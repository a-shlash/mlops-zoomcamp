# %%
# !pip freeze | grep scikit-learn
#scikit-learn==1.0.2
# Out:
# scikit-learn==1.0.2

# %%
import pickle
import pandas as pd

# %%
with open('model.bin', 'rb') as f_in:
    dv, lr = pickle.load(f_in)
# Out:
# /home/ubuntu/mlops-zoomcamp/mlops-venv/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DictVectorizer from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/ubuntu/mlops-zoomcamp/mlops-venv/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator LinearRegression from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
categorical = ['PUlocationID', 'DOlocationID']

def read_data(filename):
    df = pd.read_parquet(filename)
    
    df['duration'] = df.dropOff_datetime - df.pickup_datetime
    df['duration'] = df.duration.dt.total_seconds() / 60

    df = df[(df.duration >= 1) & (df.duration <= 60)].copy()

    df[categorical] = df[categorical].fillna(-1).astype('int').astype('str')
    
    return df

# %%
df = read_data('https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2021-02.parquet')

df.head()
# Out:
#   dispatching_base_num     pickup_datetime    dropOff_datetime PUlocationID  \
# 1      B00021          2021-02-01 00:55:40 2021-02-01 01:06:20          173
# 2      B00021          2021-02-01 00:14:03 2021-02-01 00:28:37          173
# 3      B00021          2021-02-01 00:27:48 2021-02-01 00:35:45           82
# 4               B00037 2021-02-01 00:12:50 2021-02-01 00:26:38           -1
# 5               B00037 2021-02-01 00:00:37 2021-02-01 00:09:35           -1
#
#   DOlocationID SR_Flag Affiliated_base_number   duration
# 1           82    None        B00021           10.666667
# 2           56    None        B00021           14.566667
# 3          129    None        B00021            7.950000
# 4          225    None                 B00037  13.800000
# 5           61    None                 B00037   8.966667

# %%
dicts = df[categorical].to_dict(orient='records')
X_val = dv.transform(dicts)
y_pred = lr.predict(X_val)

# %%
print(" Mean Predicted Duration is : ", round(y_pred.mean(), 2))
# Out:
#  Mean Predicted Duration is :  16.19

# %%
year = 2021
month = 2
def prepare_features(df):
    df['ride_id'] = f'{year:04d}/{month:02d}_' + df.index.astype('str')
    df['predicted_duration'] = y_pred


    return df

df_result = prepare_features(df)

# %%
df_result
# Out:
#         dispatching_base_num     pickup_datetime    dropOff_datetime  \
# 1            B00021          2021-02-01 00:55:40 2021-02-01 01:06:20
# 2            B00021          2021-02-01 00:14:03 2021-02-01 00:28:37
# 3            B00021          2021-02-01 00:27:48 2021-02-01 00:35:45
# 4                     B00037 2021-02-01 00:12:50 2021-02-01 00:26:38
# 5                     B00037 2021-02-01 00:00:37 2021-02-01 00:09:35
# ...                      ...                 ...                 ...
# 1037687               B03282 2021-02-28 23:01:16 2021-02-28 23:14:48
# 1037688               B03282 2021-02-28 23:36:10 2021-02-28 23:47:38
# 1037689      B03285          2021-02-28 23:18:36 2021-02-28 23:43:59
# 1037690      B03285          2021-02-28 23:26:34 2021-02-28 23:44:37
# 1037691      B03285          2021-02-28 23:24:00 2021-02-28 23:40:00
#
#         PUlocationID DOlocationID SR_Flag Affiliated_base_number   duration  \
# ...

# %%
output_file = f'pred_result_{year:04d}-{month:02d}.parquet'

df_result[['ride_id', 'predicted_duration']].to_parquet(
    output_file,
    engine='pyarrow',
    compression=None,
    index=False
)

# %%
import os
f_size = os.path.getsize(output_file)
print('Size of the output file: ', round(f_size/(1024*1024)))
# Out:
# Size of the output file:  19
